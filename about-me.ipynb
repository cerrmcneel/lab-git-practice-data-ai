# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Eric McNeel"
reason = "I am interested in Data Science and Machine Learning to better apply my knowlege from experience in fields outside of computer science to solve problems using data-driven approaches." \
"As the barrier to entry to data science and machine learning lowers, I want to apply these skills to fields that in the past were demed too expensive to justify the cost." 
fun_fact = "I can ride a unicycle. My goal for this course is to me more proficient in Python and to reinforce my understanding of data science and machine learning concepts that I have learned" \
" on other platforms such as Data Camp and Coursera."

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Eric McNeel. I’m excited to learn because I am interested in Data Science and Machine Learning to better apply my knowlege from experience in fields outside of computer science to solve problems using data-driven approaches.As the barrier to entry to data science and machine learning lowers, I want to apply these skills to fields that in the past were demed too expensive to justify the cost.. A fun fact about me is: I can ride a unicycle. My goal for this course is to me more proficient in Python and to reinforce my understanding of data science and machine learning concepts that I have learned on other platforms such as Data Camp and Coursera..
